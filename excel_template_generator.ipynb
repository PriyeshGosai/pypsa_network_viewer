# %%
from pypsa_network_viewer.excel_template_generator import generate_template



generate_template(
    'template8.xlsx',
    start_year=2026,
    start_month=1,
    years_duration=1,
    months_duration=None,
    days_duration=None,
    resolution_str='H',
    drop_leap_day=True,
    link_outputs=1,
    process_outputs=2,
)
# Out:
# All parameter checks passed.
# Start      : 01/01/2026 00:00
# End        : 31/12/2026 23:00
# Resolution : H
# Leap-day   : dropped
# Link outputs: 1  ->  bus0 … bus1
# Process outputs: 2  ->  bus0 … bus2
# Snapshots  : 8760
# PyPSA version: 1.1.2.post1.dev16+g70f7280ca  ->  1.1.2
# Process component: available
#
# Saved 'template8.xlsx'
#   Component sheets   : 14
#   Dynamic-var sheets : 58

# %%
import pypsa 


n = pypsa.Network()



print(n.line_types.static)

print(n.lines.static.columns)


print(n.transformer_types.static)

print(n.transformers.static.columns)
# Out:
#                                   f_nom  r_per_length  x_per_length  \
# name
# 149-AL1/24-ST1A 10.0               50.0       0.19400      0.315000
# 149-AL1/24-ST1A 110.0              50.0       0.19400      0.410000
# 149-AL1/24-ST1A 20.0               50.0       0.19400      0.337000
# 15-AL1/3-ST1A 0.4                  50.0       1.87690      0.350000
# 184-AL1/30-ST1A 110.0              50.0       0.15710      0.400000
# 184-AL1/30-ST1A 20.0               50.0       0.15710      0.330000
# 24-AL1/4-ST1A 0.4                  50.0       1.20120      0.335000
# 243-AL1/39-ST1A 110.0              50.0       0.11880      0.390000
# 243-AL1/39-ST1A 20.0               50.0       0.11880      0.320000
# 305-AL1/39-ST1A 110.0              50.0       0.09490      0.380000
# 34-AL1/6-ST1A 10.0                 50.0       0.83420      0.360000
# 34-AL1/6-ST1A 20.0                 50.0       0.83420      0.382000
# 48-AL1/8-ST1A 0.4                  50.0       0.59390      0.300000
# ...

# %%
n.lines.static
# Out:
# Empty DataFrame
# Columns: [bus0, bus1, type, x, r, g, b, s_nom, s_nom_mod, s_nom_extendable, s_nom_min, s_nom_max, s_nom_set, s_max_pu, capital_cost, overnight_cost, discount_rate, fom_cost, active, build_year, lifetime, length, carrier, terrain_factor, num_parallel, v_ang_min, v_ang_max, sub_network, x_pu, r_pu, g_pu, b_pu, x_pu_eff, r_pu_eff, s_nom_opt]
# Index: []
#
# [0 rows x 35 columns]
